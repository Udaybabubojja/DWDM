# %% [markdown]
# <a href="https://colab.research.google.com/github/Udaybabubojja/DWDM/blob/main/EXP_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/basket_analysis.csv', header=None)
data.head()
data.drop(columns=[0], inplace=True, axis=1)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
onehot_data = pd.get_dummies(data)
frequent_itemsets = apriori(onehot_data, min_support=0.1, use_colnames=True)

# %%
association_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
frequent_itemsets
# Out:
#        support                                           itemsets
# 0        0.616                                          (1_False)
# 1        0.383                                           (1_True)
# 2        0.615                                          (2_False)
# 3        0.384                                           (2_True)
# 4        0.579                                          (3_False)
# ...        ...                                                ...
# 11674    0.107  (12_False, 11_False, 10_False, 13_False, 16_Fa...
# 11675    0.101  (15_False, 12_False, 11_False, 10_False, 13_Fa...
# 11676    0.101  (15_False, 12_False, 11_False, 10_False, 16_Fa...
# 11677    0.102  (15_False, 11_False, 10_False, 13_False, 16_Fa...
# 11678    0.100  (15_False, 12_False, 10_False, 13_False, 16_Fa...
#
# [11679 rows x 2 columns]

# %%
association_rules
# Out:
#        antecedents                                        consequents  \
# 0        (1_False)                                          (2_False)
# 1        (2_False)                                          (1_False)
# 2        (1_False)                                          (3_False)
# 3        (3_False)                                          (1_False)
# 4        (1_False)                                          (4_False)
# ...            ...                                                ...
# 299633  (12_False)  (15_False, 10_False, 13_False, 16_False, 14_Fa...
# 299634  (10_False)  (15_False, 12_False, 13_False, 16_False, 14_Fa...
# 299635  (13_False)  (15_False, 12_False, 10_False, 16_False, 14_Fa...
# 299636  (16_False)  (15_False, 12_False, 10_False, 13_False, 14_Fa...
# 299637  (14_False)  (15_False, 12_False, 10_False, 13_False, 16_Fa...
#
#         antecedent support  consequent support  support  confidence      lift  \
# ...
